# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import string

# %%
rev_df=pd.read_csv('googleplaystore_user_reviews.csv')

# %%
rev_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
# App                       64295 non-null object
# Translated_Review         37427 non-null object
# Sentiment                 37432 non-null object
# Sentiment_Polarity        37432 non-null float64
# Sentiment_Subjectivity    37432 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
a=rev_df['App'].value_counts()
a=pd.DataFrame(a)
a.head()
# Out:
#                                                    App
# Angry Birds Classic                                320
# Bowmasters                                         320
# CBS Sports App - Scores, News, Stats & Watch Live  320
# 8 Ball Pool                                        300
# Helix Jump                                         300

# %%
a['Count']=a['App']

# %%
a.head()
# Out:
#                                                    App  Count
# Angry Birds Classic                                320    320
# Bowmasters                                         320    320
# CBS Sports App - Scores, News, Stats & Watch Live  320    320
# 8 Ball Pool                                        300    300
# Helix Jump                                         300    300

# %%
a['App']=a.index
a.reset_index(inplace=True,drop=True)
a.head()
# Out:
#                                                  App  Count
# 0                                Angry Birds Classic    320
# 1                                         Bowmasters    320
# 2  CBS Sports App - Scores, News, Stats & Watch Live    320
# 3                                        8 Ball Pool    300
# 4                                         Helix Jump    300

# %%
rev_df[rev_df['App']=='Angry Birds Classic']
# Out:
#                       App                                  Translated_Review  \
# 7352  Angry Birds Classic  Way many ads. I remember Angry Birds first cam...
# 7353  Angry Birds Classic  Angry Birds used game could tap play heart's c...
# 7354  Angry Birds Classic                                                NaN
# 7355  Angry Birds Classic  Good job Rovio, good job joining pay play band...
# 7356  Angry Birds Classic  The "Mighty League" part unplayable. It consta...
# 7357  Angry Birds Classic  The Miller lite beer ads really need removed. ...
# 7358  Angry Birds Classic  What happened? This fun games I really enjoyed...
# 7359  Angry Birds Classic  I played angry birds since first started. I've...
# 7360  Angry Birds Classic  It crashes lot freezes every minute. Can't eve...
# 7361  Angry Birds Classic  You know games worry life left, angry birds wo...
# 7362  Angry Birds Classic  This would great freeze time. And conveniently...
# ...

# %%
rev_df.groupby('App').describe()
# Out:
#                                                    Sentiment_Polarity  \
#                                                                 count
# App
# 10 Best Foods for You                                           194.0
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                 40.0
# 11st                                                             40.0
# 1800 Contacts - Lens Store                                       80.0
# 1LINE – One Line with One Touch                                  38.0
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif                 32.0
# 21-Day Meditation Experience                                     80.0
# 2Date Dating App, Love and matching                              38.0
# 2GIS: directory & navigator                                      40.0
# 2RedBeans                                                        39.0
# 2ndLine - Second Phone Number                                    40.0
# ...

# %%
rev_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# rev_df['length']=rev_df['Translated_Review'].apply(len)

# %%
rev_df['Translated_Review'].head()
# Out:
# 0    I like eat delicious food. That's I'm cooking ...
# 1      This help eating healthy exercise regular basis
# 2                                                  NaN
# 3           Works great especially going grocery store
# 4                                         Best idea us
# Name: Translated_Review, dtype: object

# %%
rev_df['Translated_Review'].head()
# Out:
# 0    I like eat delicious food. That's I'm cooking ...
# 1      This help eating healthy exercise regular basis
# 2                                                  NaN
# 3           Works great especially going grocery store
# 4                                         Best idea us
# Name: Translated_Review, dtype: object

# %%
# def process_Text(text):
#     nopunc=[char for char in text if char not in string.punctuation]
#     nopunc=''.join(nopunc)
#     clean_words=[word for word in nopunc.split() if word.lower()
#                 not in stopwords.words('english')]
#     return clean_words
rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
# App                       64295 non-null object
# Translated_Review         37427 non-null object
# Sentiment                 37432 non-null object
# Sentiment_Polarity        37432 non-null float64
# Sentiment_Subjectivity    37432 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
rev_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
new_df=rev_df.dropna()

# %%
new_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
new_df[new_df['Sentiment']=='Neutral']
# Out:
#                                                   App  \
# 8                               10 Best Foods for You
# 9                               10 Best Foods for You
# 22                              10 Best Foods for You
# 25                              10 Best Foods for You
# 29                              10 Best Foods for You
# 51                              10 Best Foods for You
# 56                              10 Best Foods for You
# 61                              10 Best Foods for You
# 64                              10 Best Foods for You
# 86                              10 Best Foods for You
# 87                              10 Best Foods for You
# 108                             10 Best Foods for You
# 109                             10 Best Foods for You
# 122                             10 Best Foods for You
# 125                             10 Best Foods for You
# 129                             10 Best Foods for You
# ...

# %%
new_df.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37427 entries, 0 to 64230
# Data columns (total 5 columns):
# App                       37427 non-null object
# Translated_Review         37427 non-null object
# Sentiment                 37427 non-null object
# Sentiment_Polarity        37427 non-null float64
# Sentiment_Subjectivity    37427 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize as WordTokenizer

# %%
# # nltk.download('stopwords')
# process_Text(rev_df['Translated_Review'])
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rahul\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# # word_token=word_tokenize(a)
# # from nltk.tokenize import word_tokenize as WordTokenizer

# def word_tokenizer(data, col):
#     token=[]
#     for item in data[col]:
#          token.append(WordTokenizer(item))

#     return token

# token = word_tokenizer(rev_df,'Translated_Review')
# # rev_df.insert(index, 'token_column', token)

# %%
# token

# %%
# filtered_sentence = [w for w in word_token if not w in stop_words]

# %%
# filtered_sentence = []

# for w in word_token:
#     if w not in stop_words:
#         filtered_sentence.append(w)

# print(word_token)
# print(filtered_sentence)
def process_Text(text):
    nopunc=[char for char in text if char not in string.punctuation]
    nopunc=''.join(nopunc)
    clean_words=[word for word in nopunc.split() if word.lower()
                not in stopwords.words('english')]
    return clean_words

# %%
# new_df_1=new_df.sample(frac=0.40,random_state=47)

# %%
# new_df_1.info()

# %%
new_df['Translated_Review'].apply(process_Text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\rahul/nltk_data'
# ...

# %%
# len(filtered_sentence)

# %%
# from nltk.probability import FreqDist
# fdist=FreqDist()

# %%
# for word in word_token:
#     fdist[word.lower()]+=1
# fdist

# %%
# rev_df['Translated_Review'].describe()

# %%
# rev_df['Translated_Review'].shape

# %%
# rev_df['Sentiment'].describe()

# %%
# rev_df['Sentiment'].shape

# %% [markdown]
# ### Creating model

# %%
from sklearn.model_selection import train_test_split

# %%
rev_train,rev_test,sent_train,sent_test=train_test_split(new_df['Translated_Review'],new_df['Sentiment'],test_size=0.2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report,confusion_matrix

# %%
pipeline=Pipeline([
    ('bow',CountVectorizer(analyzer=process_Text)), # converts strings to integer counts
    ('tfidf',TfidfTransformer()), # converts integer counts to weighted TF-IDF scores
    ('classifier',MultinomialNB()) # train on TF-IDF vectors with Naive Bayes classifier
])

# %%
pipeline.fit(rev_train,sent_train)

# %%
prediction=pipeline.predict(rev_test)
prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-37263b9c462b> in <module>
# ----> 1 prediction=pipeline.predict(rev_test)
#       2 prediction
#
# NameError: name 'pipeline' is not defined

# %%
print(classification_report(sent_test,prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1cc4e72c51a7> in <module>
# ----> 1 print(classification_report(sent_test,prediction))
#
# NameError: name 'classification_report' is not defined

# %%
myem=pd.Series(['worse'])
pipeline.predict(myem)
